# %%
import numpy as np
import matplotlib.pylab as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.arange(-5.0, 5.0 , 0.1)
y = sigmoid(x)
plt.plot(x,y)
plt.ylim(-0.1,1.1)
plt.show()

# %%
#Tanh
def tanh(x):
    return np.tanh(x)

#그래프 그리기
x = np.arange(-5.0, 5.0, 0.1)
y = tanh(x)
plt.plot(x,y)
plt.ylim(-1.1, 1.1)
plt.title("Tanh Activation Function")
plt.grid()
plt.show()

# %%
def relu(x):
    return np.maximum(0,x)

x = np.arange(-5.0, 5.0, 0.1)
y = relu(x)
plt.plot(x,y)
plt.ylim(-0.5, 5.5)
plt.title("RelU Activation function")
plt.grid()
plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib as plt

# 폰트지정
plt.rcParams['font.family'] = 'Malgun Gothic'

# 마이너스 부호 깨짐 지정
plt.rcParams['axes.unicode_minus'] = False

# 데이터 준비
x_data = np.array([0,1,2,3,4], dtype=np.float32)
y_data = np.array([1,3,5,7,9], dtype=np.float32)

#모델 정의
w = tf.Variable(0.0)
b = tf.Variable(0.0)

#예측 함수
def predict(x):
    return w * x + b

#손실 함수 정의
def loss_fn(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true - y_pred))

#최적화 알고리즘 선택
optimizer = tf._optimizers.SGD(learning_rate = 0.01) #확률적 경사 하강법

#학습 과정
for step in range(100):
    with tf.GradientTape() as tape:
        y_pred = predict(x_data)
        loss = loss_fn(y_data, y_pred)
        
        #가중치와 편향에 대한 경사도 계산 및 업데이트
        gradients = tape.gradient(loss, [w,b])
        optimizer.apply_gradients(zip(gradients, [w,b]))
        
        if step % 10 == 0: 
            print(f"Step {step}, loss: {loss.numpy()}, w: {w.numpy()}, b:{b.numpy}")
# Out:
# Step 0, loss: 33.0, w: 0.2800000011920929, b:<bound method BaseResourceVariable.numpy of <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.09999999403953552>>
# Step 10, loss: 1.8755830526351929, w: 1.6574040651321411, b:<bound method BaseResourceVariable.numpy of <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.6004058718681335>>
# Step 20, loss: 0.1229294165968895, w: 1.9802603721618652, b:<bound method BaseResourceVariable.numpy of <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.7298945188522339>>
# Step 30, loss: 0.02239181473851204, w: 2.053251266479492, b:<bound method BaseResourceVariable.numpy of <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.7707916498184204>>
# Step 40, loss: 0.014991003088653088, w: 2.0671944618225098, b:<bound method BaseResourceVariable.numpy of <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.7900874018669128>>
# Step 50, loss: 0.013025246560573578, w: 2.0673303604125977, b:<bound method BaseResourceVariable.numpy of <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.8037028312683105>>
# Step 60, loss: 0.011540031060576439, w: 2.06437611579895, b:<bound method BaseResourceVariable.numpy of <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.8154456615447998>>
# Step 70, loss: 0.010236968286335468, w: 2.0608623027801514, b:<bound method BaseResourceVariable.numpy of <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.8262498378753662>>
# Step 80, loss: 0.009081726893782616, w: 2.0573794841766357, b:<bound method BaseResourceVariable.numpy of <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.8363654017448425>>
# Step 90, loss: 0.00805690512061119, w: 2.0540578365325928, b:<bound method BaseResourceVariable.numpy of <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.8458786010742188>>

# %%
print("Final Parameters:", f"w={w.numpy()}, b={b.numpy()}")
print("Prediction for x = 5: ", predict(5).numpy())
# Out:
# Final Parameters: w=2.051225423812866, b=0.8539638519287109
# Prediction for x = 5:  11.110091

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

#데이터 준비
x_data = np.array([0,1,2,3,4], dtype=np.float32)
y_data = np.array([1,3,5,7,9], dtype=np.float32)

#모델 정의
model = Sequential([
    Dense(1, input_dim = 1)
])
# Out:
# c:\ai_study\ai_project\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#모델 컴파일
model.compile(optimizer='sgd', loss='mse')

# %%
#모델 학습
model.fit(x_data, y_data, epochs=50, verbose=1) #50번 반복학습
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 12.7917
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 9.6162
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 7.2346
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 5.4483
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 4.1085
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 3.1036
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.3497
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.7840
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.3596
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.0411
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.8020
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.6224
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.4875
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.3861
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.3098
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2523
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.2090
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1763
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1515
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1327
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1183
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1074
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0989
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0924
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0872
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0832
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0799
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0773
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0751
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0732
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0716
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0702
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0690
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0679
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0668
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0659
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0650
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0641
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0633
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0625
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0617
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0609
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0602
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0594
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0587
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0580
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0573
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0566
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0559
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0553

# %%
x_new = np.array([5], dtype=np.float32)
y_new = model.predict(x_new)

print(f"x = 5 일 때, 예측된 y = {y_new[0][0]:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# x = 5 일 때, 예측된 y = 11.30

# %%
import tensorflow as tf #딥러닝 라이브러리
from tensorflow.keras import layers, models #신경망 계층 및 모델 설계
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

#데이터 전처리
#MNIST 데이터셋은 이미 나눠서 제공
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
#MNIST 이미지는 28x28 크기, 채널 정보 추가 (흑백 이미지는 채널 1개)
x_train = x_train.reshape((x_train.shape[0], 28, 28, 1)).astype('float32') / 255.0  # 0~1로 정규화
x_test = x_test.reshape((x_test.shape[0], 28, 28, 1)).astype('float32') / 255.0

# %%
# 레이블을 One-Hot Encoding (숫자 0~9를 벡터로 변환)
# One-Hot Encoding : 범주형 데이터를 수치형 데이터로 변환하는 방법
if len(y_train.shape) == 1:  # shape이 (n,)인지 확인
    y_train = tf.keras.utils.to_categorical(y_train, 10)
if len(y_test.shape) == 1:  # shape이 (n,)인지 확인
    y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
#모델 정의
model = models.Sequential() #순차적 모델 선언

# %%
# 첫 번째 합성곱 계층: 필터 크기 3x3, 필터 수 32, 활성화 함수 ReLU
model.add(layers.Conv2D(32,(3,3), activation='relu', input_shape=(28,28,1)))
# 풀링 계층: 2x2 크기로 다운샘플링
model.add(layers.MaxPooling2D((2,2)))

# %%
# 두 번째 합성곱 계층: 필터 수 64
model.add(layers.Conv2D(64,(3,3), activation="relu"))
model.add(layers.MaxPooling2D((2, 2)))

# %%
# 세 번째 합성공 계층: 필터 수 64
model.add(layers.Conv2D(64,(3,3), activation="relu"))

# %%
#Fully Connected Layer를 연결하기 위해 Flatten(압축) 처리
model.add(layers.Flatten())

# %%
# 출력층: 뉴런 수 10(클래스 수), 활성화 함수 Softmax
model.add(layers.Dense(10, activation='softmax'))

# %%
#모델 요약 출력(구조 확인)
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 3, 3, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 576)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         5,770 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61,514 (240.29 KB)
#  Trainable params: 61,514 (240.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 모델 컴파일
model.compile(optimizer='adam', #최적화 알고리즘
              loss='categorical_crossentropy', #다중 클래스 분류 손실 함수
              metrics=['accuracy']) # 평가 지표 : 정확도

# %%
# 모델 학습
history = model.fit(x_train, y_train, epochs=50, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9926 - loss: 0.0209 - val_accuracy: 0.9890 - val_loss: 0.0407
# Epoch 2/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9938 - loss: 0.0184 - val_accuracy: 0.9901 - val_loss: 0.0384
# Epoch 3/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9953 - loss: 0.0134 - val_accuracy: 0.9854 - val_loss: 0.0540
# Epoch 4/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9960 - loss: 0.0127 - val_accuracy: 0.9880 - val_loss: 0.0503
# Epoch 5/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9970 - loss: 0.0093 - val_accuracy: 0.9877 - val_loss: 0.0522
# Epoch 6/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9972 - loss: 0.0085 - val_accuracy: 0.9902 - val_loss: 0.0428
# Epoch 7/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9975 - loss: 0.0069 - val_accuracy: 0.9892 - val_loss: 0.0546
# Epoch 8/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9984 - loss: 0.0044 - val_accuracy: 0.9887 - val_loss: 0.0524
# Epoch 9/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9972 - loss: 0.0075 - val_accuracy: 0.9887 - val_loss: 0.0513
# Epoch 10/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9985 - loss: 0.0053 - val_accuracy: 0.9914 - val_loss: 0.0492
# Epoch 11/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9989 - loss: 0.0034 - val_accuracy: 0.9913 - val_loss: 0.0514
# Epoch 12/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 0.9877 - val_loss: 0.0616
# Epoch 13/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9972 - loss: 0.0076 - val_accuracy: 0.9912 - val_loss: 0.0505
# Epoch 14/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9986 - loss: 0.0046 - val_accuracy: 0.9895 - val_loss: 0.0529
# Epoch 15/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9988 - loss: 0.0038 - val_accuracy: 0.9904 - val_loss: 0.0590
# Epoch 16/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9990 - loss: 0.0031 - val_accuracy: 0.9906 - val_loss: 0.0589
# Epoch 17/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9991 - loss: 0.0026 - val_accuracy: 0.9918 - val_loss: 0.0556
# Epoch 18/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9993 - loss: 0.0023 - val_accuracy: 0.9896 - val_loss: 0.0613
# Epoch 19/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9983 - loss: 0.0051 - val_accuracy: 0.9896 - val_loss: 0.0592
# Epoch 20/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9986 - loss: 0.0038 - val_accuracy: 0.9897 - val_loss: 0.0629
# Epoch 21/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9988 - loss: 0.0033 - val_accuracy: 0.9912 - val_loss: 0.0582
# Epoch 22/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9988 - loss: 0.0027 - val_accuracy: 0.9900 - val_loss: 0.0613
# Epoch 23/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.9882 - val_loss: 0.0865
# Epoch 24/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9981 - loss: 0.0046 - val_accuracy: 0.9890 - val_loss: 0.0669
# Epoch 25/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9990 - loss: 0.0027 - val_accuracy: 0.9902 - val_loss: 0.0631
# Epoch 26/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9993 - loss: 0.0019 - val_accuracy: 0.9883 - val_loss: 0.0768
# Epoch 27/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9987 - loss: 0.0036 - val_accuracy: 0.9900 - val_loss: 0.0639
# Epoch 28/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9993 - loss: 0.0020 - val_accuracy: 0.9906 - val_loss: 0.0655
# Epoch 29/50
# 395/750 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9999 - loss: 3.7062e-04

# %%
#모델 평가
test_loss, test_acc = model.evaluate(x_test,y_test)
print(f"테스트 정확도: {test_acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9851 - loss: 0.0454
# 테스트 정확도: 0.9886

# %%
import numpy as np

sample_image = x_test[0] #첫번째 이미지 저장
sample_label = np.argmax(y_test[0]) # y_test[0] 배열에서 가장 큰 값을 가지는 요소의 인덱스를 찾아 sample_label 변수에 저장합니다.

# %%
#모델로 예측 수행
predicted_label = np.argmax(model.predict(sample_image.reshape(1,28,28,1))) # 1px 너비28 높이28 마지막 1뭐지?
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step

# %%
plt.imshow(sample_image.reshape(28,28), cmap='gray')
plt.title(f"real value: {sample_label}, forcast value:{predicted_label}")
plt.show()
